# %%
import urllib3, json, base64
openApiURL = "http://aiopen.etri.re.kr:8000/ObjectDetect"

# %%
with open('etriaikey.txt') as f:
    ai_key = f.read()

# %%
img_file = '사진/공원.jpg'
img_type = img_file.split('.')[-1]
img_type
# Out:
# 'jpg'

# %%
img_type = 'jpg' if img_type == 'jfif' else img_type

# %%
with open(img_file, "rb") as file:
    img_contents = base64.b64encode(file.read()).decode("utf8")

# %%
request_json = {
    "access_key": ai_key,
    "argument": {
        "type": img_type,
        "file": img_contents
    }
}

# %%
http = urllib3.PoolManager()
response = http.request(
    "POST",
    openApiURL,
    headers={"Content-Type": "application/json; charset=UTF-8"},
    body=json.dumps(request_json)
)

# %%
response.status
# Out:
# 200

# %%
result = json.loads(response.data)
obj_list = result['return_object']['data']

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt

# %%
img = Image.open(img_file)
plt.imshow(img);

# %%
draw = ImageDraw.Draw(img)
for obj in obj_list:
    name = obj['class']
    x = int(obj['x'])
    y = int(obj['y'])
    w = int(obj['width'])
    h = int(obj['height'])
    draw.rectangle(((x,y), (x+w,y+h)), outline=(255,0,0), width=2)
    draw.text((x+10, y-20), name, font=ImageFont.truetype('malgun.ttf',20), fill=(0,0,255))

# %%
plt.figure(figsize=(12,8))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
from glob import glob
glob('사진/*.jpg')
# Out:
# ['사진\\bee.jpg',
#  '사진\\canal.jpg',
#  '사진\\cat.jpg',
#  '사진\\cat3(toto).jpg',
#  '사진\\cocker-spaniel.jpg',
#  '사진\\desert.jpg',
#  '사진\\dog1.jpg',
#  '사진\\dog2.jpg',
#  '사진\\fashion.jpg',
#  '사진\\flower1.jpg',
#  '사진\\flower2.jpg',
#  '사진\\keyboard.jpg',
#  '사진\\letters.jpg',
#  '사진\\noise.jpg',
#  '사진\\puppy.jpg',
#  '사진\\snow.jpg',
#  '사진\\star.jpg',
#  '사진\\taiwan.jpg',
#  '사진\\train.jpg',
#  '사진\\train2.jpg',
#  '사진\\travel.jpg',
#  '사진\\tree.jpg',
#  '사진\\공원.jpg']

# %%
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# http = urllib3.PoolManager()          # 프로그램 안에서 한번만 실행하면 됨
for img_file in glob('사진/*.jpg'):
    img_type = img_file.split('.')[-1]
    img_type = 'jpg' if img_type == 'jfif' else img_type
    with open(img_file, "rb") as file:
        img_contents = base64.b64encode(file.read()).decode("utf8")

    request_json = {
        "access_key": ai_key,
        "argument": {
            "type": img_type,
            "file": img_contents
        }
    }
    response = http.request(
        "POST",
        openApiURL,
        headers={"Content-Type": "application/json; charset=UTF-8"},
        body=json.dumps(request_json)
    )
    if response.status != 200:
        continue

    result = json.loads(response.data)
    obj_list = result['return_object']['data']
    img = Image.open(img_file)
    draw = ImageDraw.Draw(img)
    for obj in obj_list:
        name = obj['class']
        x = int(obj['x'])
        y = int(obj['y'])
        w = int(obj['width'])
        h = int(obj['height'])
        draw.rectangle(((x,y), (x+w,y+h)), outline=(255,0,0), width=2)
        draw.text((x+10, y-20), name, font=ImageFont.truetype('malgun.ttf',20), fill=(255,0,0))

    plt.figure(figsize=(12,8))
    plt.imshow(img)
    plt.axis('off'), plt.title(img_file.split('\\')[-1])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-ddcd9e0884b4> in <module>
#      23
#      24     result = json.loads(response.data)
# ---> 25     obj_list = result['return_object']['data']
#      26     img = Image.open(img_file)
#      27     draw = ImageDraw.Draw(img)
#
# KeyError: 'data'

# %% [markdown]
# # Cifer-10 이미지 분류 v1

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v1.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %%
hist = model.fit(
    X_train, Y_train, validation_split=0.2,
    epochs=100, batch_size=32, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.57035, saving model to best-cifar10-v1.h5
# 1250/1250 - 34s - loss: 1.8274 - accuracy: 0.3280 - val_loss: 1.5704 - val_accuracy: 0.4275 - 34s/epoch - 27ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.57035 to 1.38037, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.5201 - accuracy: 0.4430 - val_loss: 1.3804 - val_accuracy: 0.5044 - 22s/epoch - 17ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.38037 to 1.26975, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.3936 - accuracy: 0.4955 - val_loss: 1.2697 - val_accuracy: 0.5545 - 22s/epoch - 17ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.26975 to 1.23473, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 1.2963 - accuracy: 0.5359 - val_loss: 1.2347 - val_accuracy: 0.5561 - 23s/epoch - 18ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.23473 to 1.20193, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.2167 - accuracy: 0.5665 - val_loss: 1.2019 - val_accuracy: 0.5782 - 22s/epoch - 17ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.20193 to 1.05929, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.1543 - accuracy: 0.5913 - val_loss: 1.0593 - val_accuracy: 0.6312 - 22s/epoch - 17ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss did not improve from 1.05929
# 1250/1250 - 22s - loss: 1.1000 - accuracy: 0.6161 - val_loss: 1.0638 - val_accuracy: 0.6227 - 22s/epoch - 17ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.05929 to 0.98452, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.0541 - accuracy: 0.6310 - val_loss: 0.9845 - val_accuracy: 0.6533 - 22s/epoch - 17ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 0.98452 to 0.96719, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 1.0125 - accuracy: 0.6461 - val_loss: 0.9672 - val_accuracy: 0.6605 - 22s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.96719
# 1250/1250 - 22s - loss: 0.9782 - accuracy: 0.6574 - val_loss: 0.9795 - val_accuracy: 0.6526 - 22s/epoch - 17ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.96719 to 0.88387, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.9489 - accuracy: 0.6693 - val_loss: 0.8839 - val_accuracy: 0.6912 - 23s/epoch - 18ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.88387 to 0.87129, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.9217 - accuracy: 0.6779 - val_loss: 0.8713 - val_accuracy: 0.6939 - 22s/epoch - 18ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.87129
# 1250/1250 - 22s - loss: 0.8984 - accuracy: 0.6893 - val_loss: 0.8757 - val_accuracy: 0.6907 - 22s/epoch - 17ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.87129 to 0.82634, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8767 - accuracy: 0.6976 - val_loss: 0.8263 - val_accuracy: 0.7097 - 22s/epoch - 18ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.82634
# 1250/1250 - 22s - loss: 0.8527 - accuracy: 0.7065 - val_loss: 0.8306 - val_accuracy: 0.7113 - 22s/epoch - 17ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.82634 to 0.81057, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.8390 - accuracy: 0.7085 - val_loss: 0.8106 - val_accuracy: 0.7214 - 23s/epoch - 18ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.81057 to 0.78018, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.8210 - accuracy: 0.7162 - val_loss: 0.7802 - val_accuracy: 0.7275 - 23s/epoch - 18ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.78018 to 0.77215, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.8033 - accuracy: 0.7229 - val_loss: 0.7721 - val_accuracy: 0.7307 - 22s/epoch - 18ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.77215
# 1250/1250 - 22s - loss: 0.7940 - accuracy: 0.7243 - val_loss: 0.7751 - val_accuracy: 0.7328 - 22s/epoch - 17ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.77215 to 0.76223, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7812 - accuracy: 0.7326 - val_loss: 0.7622 - val_accuracy: 0.7387 - 22s/epoch - 17ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss improved from 0.76223 to 0.75664, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7702 - accuracy: 0.7342 - val_loss: 0.7566 - val_accuracy: 0.7384 - 22s/epoch - 17ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss did not improve from 0.75664
# 1250/1250 - 23s - loss: 0.7613 - accuracy: 0.7376 - val_loss: 0.7719 - val_accuracy: 0.7384 - 23s/epoch - 18ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss improved from 0.75664 to 0.73857, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7529 - accuracy: 0.7413 - val_loss: 0.7386 - val_accuracy: 0.7494 - 23s/epoch - 18ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss improved from 0.73857 to 0.72410, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7374 - accuracy: 0.7464 - val_loss: 0.7241 - val_accuracy: 0.7521 - 23s/epoch - 18ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.72410 to 0.72210, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7371 - accuracy: 0.7477 - val_loss: 0.7221 - val_accuracy: 0.7511 - 23s/epoch - 18ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss improved from 0.72210 to 0.71427, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7257 - accuracy: 0.7525 - val_loss: 0.7143 - val_accuracy: 0.7561 - 22s/epoch - 17ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss improved from 0.71427 to 0.71214, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7226 - accuracy: 0.7552 - val_loss: 0.7121 - val_accuracy: 0.7601 - 22s/epoch - 17ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.71214
# 1250/1250 - 22s - loss: 0.7153 - accuracy: 0.7579 - val_loss: 0.7141 - val_accuracy: 0.7546 - 22s/epoch - 17ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss improved from 0.71214 to 0.69691, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.7120 - accuracy: 0.7575 - val_loss: 0.6969 - val_accuracy: 0.7599 - 22s/epoch - 17ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss improved from 0.69691 to 0.69099, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.7060 - accuracy: 0.7615 - val_loss: 0.6910 - val_accuracy: 0.7625 - 23s/epoch - 18ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.69099
# 1250/1250 - 22s - loss: 0.6993 - accuracy: 0.7608 - val_loss: 0.7058 - val_accuracy: 0.7601 - 22s/epoch - 17ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.69099
# 1250/1250 - 22s - loss: 0.6987 - accuracy: 0.7604 - val_loss: 0.7199 - val_accuracy: 0.7563 - 22s/epoch - 17ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.69099
# 1250/1250 - 22s - loss: 0.6910 - accuracy: 0.7660 - val_loss: 0.6976 - val_accuracy: 0.7608 - 22s/epoch - 17ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.69099
# 1250/1250 - 23s - loss: 0.6834 - accuracy: 0.7698 - val_loss: 0.6926 - val_accuracy: 0.7631 - 23s/epoch - 18ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.69099
# 1250/1250 - 23s - loss: 0.6808 - accuracy: 0.7673 - val_loss: 0.7119 - val_accuracy: 0.7576 - 23s/epoch - 18ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.69099
# 1250/1250 - 23s - loss: 0.6846 - accuracy: 0.7682 - val_loss: 0.7149 - val_accuracy: 0.7570 - 23s/epoch - 18ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.69099 to 0.68411, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6771 - accuracy: 0.7685 - val_loss: 0.6841 - val_accuracy: 0.7646 - 22s/epoch - 17ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.68411
# 1250/1250 - 23s - loss: 0.6746 - accuracy: 0.7699 - val_loss: 0.6845 - val_accuracy: 0.7685 - 23s/epoch - 18ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.68411
# 1250/1250 - 23s - loss: 0.6651 - accuracy: 0.7763 - val_loss: 0.6861 - val_accuracy: 0.7661 - 23s/epoch - 18ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.68411 to 0.67617, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6625 - accuracy: 0.7771 - val_loss: 0.6762 - val_accuracy: 0.7676 - 23s/epoch - 18ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.67617 to 0.67533, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6584 - accuracy: 0.7774 - val_loss: 0.6753 - val_accuracy: 0.7692 - 22s/epoch - 17ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.67533
# 1250/1250 - 23s - loss: 0.6592 - accuracy: 0.7796 - val_loss: 0.6901 - val_accuracy: 0.7672 - 23s/epoch - 18ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.67533 to 0.66696, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6502 - accuracy: 0.7804 - val_loss: 0.6670 - val_accuracy: 0.7734 - 23s/epoch - 18ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.66696
# 1250/1250 - 22s - loss: 0.6547 - accuracy: 0.7782 - val_loss: 0.6799 - val_accuracy: 0.7719 - 22s/epoch - 17ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.66696
# 1250/1250 - 22s - loss: 0.6529 - accuracy: 0.7807 - val_loss: 0.6778 - val_accuracy: 0.7782 - 22s/epoch - 17ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.66696
# 1250/1250 - 23s - loss: 0.6462 - accuracy: 0.7812 - val_loss: 0.6739 - val_accuracy: 0.7744 - 23s/epoch - 18ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss improved from 0.66696 to 0.65660, saving model to best-cifar10-v1.h5
# 1250/1250 - 22s - loss: 0.6480 - accuracy: 0.7826 - val_loss: 0.6566 - val_accuracy: 0.7791 - 22s/epoch - 17ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.65660
# 1250/1250 - 22s - loss: 0.6356 - accuracy: 0.7860 - val_loss: 0.6589 - val_accuracy: 0.7773 - 22s/epoch - 17ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.65660
# 1250/1250 - 23s - loss: 0.6365 - accuracy: 0.7867 - val_loss: 0.6710 - val_accuracy: 0.7752 - 23s/epoch - 18ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.65660
# 1250/1250 - 23s - loss: 0.6315 - accuracy: 0.7868 - val_loss: 0.6761 - val_accuracy: 0.7742 - 23s/epoch - 18ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss improved from 0.65660 to 0.64946, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6302 - accuracy: 0.7865 - val_loss: 0.6495 - val_accuracy: 0.7810 - 23s/epoch - 18ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.64946
# 1250/1250 - 22s - loss: 0.6358 - accuracy: 0.7878 - val_loss: 0.6648 - val_accuracy: 0.7743 - 22s/epoch - 17ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.64946
# 1250/1250 - 23s - loss: 0.6252 - accuracy: 0.7885 - val_loss: 0.6545 - val_accuracy: 0.7790 - 23s/epoch - 18ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss improved from 0.64946 to 0.64900, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6320 - accuracy: 0.7892 - val_loss: 0.6490 - val_accuracy: 0.7797 - 23s/epoch - 18ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.64900
# 1250/1250 - 23s - loss: 0.6229 - accuracy: 0.7912 - val_loss: 0.6713 - val_accuracy: 0.7775 - 23s/epoch - 18ms/step
# Epoch 56/100
#
# Epoch 00056: val_loss did not improve from 0.64900
# 1250/1250 - 22s - loss: 0.6240 - accuracy: 0.7908 - val_loss: 0.6554 - val_accuracy: 0.7829 - 22s/epoch - 17ms/step
# Epoch 57/100
#
# Epoch 00057: val_loss did not improve from 0.64900
# 1250/1250 - 22s - loss: 0.6223 - accuracy: 0.7914 - val_loss: 0.6579 - val_accuracy: 0.7836 - 22s/epoch - 17ms/step
# Epoch 58/100
#
# Epoch 00058: val_loss did not improve from 0.64900
# 1250/1250 - 23s - loss: 0.6213 - accuracy: 0.7940 - val_loss: 0.6990 - val_accuracy: 0.7792 - 23s/epoch - 18ms/step
# Epoch 59/100
#
# Epoch 00059: val_loss did not improve from 0.64900
# 1250/1250 - 22s - loss: 0.6160 - accuracy: 0.7941 - val_loss: 0.6772 - val_accuracy: 0.7750 - 22s/epoch - 17ms/step
# Epoch 60/100
#
# Epoch 00060: val_loss did not improve from 0.64900
# 1250/1250 - 23s - loss: 0.6131 - accuracy: 0.7957 - val_loss: 0.6991 - val_accuracy: 0.7708 - 23s/epoch - 18ms/step
# Epoch 61/100
#
# Epoch 00061: val_loss did not improve from 0.64900
# 1250/1250 - 22s - loss: 0.6156 - accuracy: 0.7963 - val_loss: 0.6565 - val_accuracy: 0.7838 - 22s/epoch - 17ms/step
# Epoch 62/100
#
# Epoch 00062: val_loss did not improve from 0.64900
# 1250/1250 - 22s - loss: 0.6072 - accuracy: 0.7980 - val_loss: 0.6810 - val_accuracy: 0.7751 - 22s/epoch - 17ms/step
# Epoch 63/100
#
# Epoch 00063: val_loss did not improve from 0.64900
# 1250/1250 - 23s - loss: 0.6129 - accuracy: 0.7952 - val_loss: 0.6653 - val_accuracy: 0.7765 - 23s/epoch - 18ms/step
# Epoch 64/100
#
# Epoch 00064: val_loss improved from 0.64900 to 0.64312, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.6153 - accuracy: 0.7936 - val_loss: 0.6431 - val_accuracy: 0.7877 - 23s/epoch - 18ms/step
# Epoch 65/100
#
# Epoch 00065: val_loss did not improve from 0.64312
# 1250/1250 - 22s - loss: 0.6091 - accuracy: 0.7975 - val_loss: 0.6643 - val_accuracy: 0.7799 - 22s/epoch - 17ms/step
# Epoch 66/100
#
# Epoch 00066: val_loss did not improve from 0.64312
# 1250/1250 - 23s - loss: 0.6048 - accuracy: 0.7985 - val_loss: 0.6696 - val_accuracy: 0.7814 - 23s/epoch - 18ms/step
# Epoch 67/100
#
# Epoch 00067: val_loss did not improve from 0.64312
# 1250/1250 - 22s - loss: 0.6006 - accuracy: 0.7990 - val_loss: 0.6470 - val_accuracy: 0.7913 - 22s/epoch - 17ms/step
# Epoch 68/100
#
# Epoch 00068: val_loss did not improve from 0.64312
# 1250/1250 - 22s - loss: 0.6078 - accuracy: 0.7983 - val_loss: 0.6457 - val_accuracy: 0.7878 - 22s/epoch - 17ms/step
# Epoch 69/100
#
# Epoch 00069: val_loss did not improve from 0.64312
# 1250/1250 - 23s - loss: 0.6021 - accuracy: 0.8001 - val_loss: 0.6489 - val_accuracy: 0.7843 - 23s/epoch - 18ms/step
# Epoch 70/100
#
# Epoch 00070: val_loss did not improve from 0.64312
# 1250/1250 - 21s - loss: 0.6044 - accuracy: 0.7978 - val_loss: 0.6617 - val_accuracy: 0.7826 - 21s/epoch - 17ms/step
# Epoch 71/100
#
# Epoch 00071: val_loss did not improve from 0.64312
# 1250/1250 - 22s - loss: 0.6037 - accuracy: 0.8014 - val_loss: 0.6488 - val_accuracy: 0.7898 - 22s/epoch - 18ms/step
# Epoch 72/100
#
# Epoch 00072: val_loss did not improve from 0.64312
# 1250/1250 - 23s - loss: 0.6028 - accuracy: 0.7996 - val_loss: 0.6774 - val_accuracy: 0.7798 - 23s/epoch - 18ms/step
# Epoch 73/100
#
# Epoch 00073: val_loss improved from 0.64312 to 0.64275, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.5966 - accuracy: 0.8007 - val_loss: 0.6428 - val_accuracy: 0.7910 - 23s/epoch - 18ms/step
# Epoch 74/100
#
# Epoch 00074: val_loss did not improve from 0.64275
# 1250/1250 - 22s - loss: 0.5943 - accuracy: 0.8019 - val_loss: 0.6977 - val_accuracy: 0.7731 - 22s/epoch - 17ms/step
# Epoch 75/100
#
# Epoch 00075: val_loss improved from 0.64275 to 0.63356, saving model to best-cifar10-v1.h5
# 1250/1250 - 23s - loss: 0.5928 - accuracy: 0.8039 - val_loss: 0.6336 - val_accuracy: 0.7915 - 23s/epoch - 18ms/step
# Epoch 76/100
#
# Epoch 00076: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5972 - accuracy: 0.8028 - val_loss: 0.6598 - val_accuracy: 0.7908 - 22s/epoch - 17ms/step
# Epoch 77/100
#
# Epoch 00077: val_loss did not improve from 0.63356
# 1250/1250 - 23s - loss: 0.5960 - accuracy: 0.8008 - val_loss: 0.6466 - val_accuracy: 0.7927 - 23s/epoch - 18ms/step
# Epoch 78/100
#
# Epoch 00078: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5990 - accuracy: 0.8015 - val_loss: 0.6516 - val_accuracy: 0.7861 - 22s/epoch - 17ms/step
# Epoch 79/100
#
# Epoch 00079: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5904 - accuracy: 0.8022 - val_loss: 0.6563 - val_accuracy: 0.7817 - 22s/epoch - 17ms/step
# Epoch 80/100
#
# Epoch 00080: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5837 - accuracy: 0.8049 - val_loss: 0.6742 - val_accuracy: 0.7851 - 22s/epoch - 17ms/step
# Epoch 81/100
#
# Epoch 00081: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5917 - accuracy: 0.8045 - val_loss: 0.6392 - val_accuracy: 0.7918 - 22s/epoch - 18ms/step
# Epoch 82/100
#
# Epoch 00082: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5867 - accuracy: 0.8029 - val_loss: 0.6899 - val_accuracy: 0.7716 - 22s/epoch - 17ms/step
# Epoch 83/100
#
# Epoch 00083: val_loss did not improve from 0.63356
# 1250/1250 - 23s - loss: 0.5885 - accuracy: 0.8056 - val_loss: 0.6569 - val_accuracy: 0.7880 - 23s/epoch - 18ms/step
# Epoch 84/100
#
# Epoch 00084: val_loss did not improve from 0.63356
# 1250/1250 - 23s - loss: 0.5927 - accuracy: 0.8028 - val_loss: 0.6651 - val_accuracy: 0.7809 - 23s/epoch - 18ms/step
# Epoch 85/100
#
# Epoch 00085: val_loss did not improve from 0.63356
# 1250/1250 - 22s - loss: 0.5890 - accuracy: 0.8019 - val_loss: 0.6575 - val_accuracy: 0.7847 - 22s/epoch - 17ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.6478 - accuracy: 0.7864
# [0.6478052139282227, 0.7864000201225281]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, 'o-', ms=3, label='train accuracy')
plt.plot(xs, y_vloss, 'o-', ms=3, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('Epoch')
plt.show()

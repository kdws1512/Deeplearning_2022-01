# %% [markdown]
# # Cifer-10 이미지 분류 v2
#
# - 데이터 부풀리기 적용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
X_train = X_train.astype('float32') / 255.
X_test = X_test.astype(np.float32) / 255.

# %%
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(32,32,3), activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=RMSprop(learning_rate=0.0001, decay=1e-6),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size=0.2, random_state=seed
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False, # set input mean to 0 over the dataset
    samplewise_center=False, # set each sample mean to 0
    featurewise_std_normalization=False, # divide inputs by std of dataset
    samplewise_std_normalization=False, # divide each input by its std
    zca_whitening=False, # apply ZCA whitening
    zca_epsilon=1e-06, # epsilon for ZCA whitening
    rotation_range=0, # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1, # randomly shift images horizontally
    height_shift_range=0.1, # randomly shift images vertically
    shear_range=0., # set range for random shear
    zoom_range=0.1, # set range for random zoom
    channel_shift_range=0., # set range for random channel shifts
    fill_mode='nearest', # set mode for filling points outside the input boundaries
    cval=0., # value used for fill_mode = "constant"
    horizontal_flip=True, # randomly flip images
    vertical_flip=False, # randomly flip images
    rescale=None, # set rescaling factor (applied before any other transformation)
    preprocessing_function=None, # set function that will be applied on each input
    data_format=None, # image data format, either "channels_first" or "channels_last"
    validation_split=0.0 # fraction of images reserved for validation
)
datagen.fit(X_train)

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size=32),
    validation_data=(X_valid, Y_valid),
    epochs=100, verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.57048, saving model to best-cifar10-v2.h5
# 1250/1250 - 38s - loss: 1.8903 - accuracy: 0.3027 - val_loss: 1.5705 - val_accuracy: 0.4306 - 38s/epoch - 30ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.57048 to 1.45179, saving model to best-cifar10-v2.h5
# 1250/1250 - 34s - loss: 1.6104 - accuracy: 0.4066 - val_loss: 1.4518 - val_accuracy: 0.4681 - 34s/epoch - 27ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.45179 to 1.37514, saving model to best-cifar10-v2.h5
# 1250/1250 - 34s - loss: 1.5043 - accuracy: 0.4541 - val_loss: 1.3751 - val_accuracy: 0.5027 - 34s/epoch - 27ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.37514 to 1.27275, saving model to best-cifar10-v2.h5
# 1250/1250 - 33s - loss: 1.4232 - accuracy: 0.4854 - val_loss: 1.2728 - val_accuracy: 0.5451 - 33s/epoch - 26ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.27275 to 1.25271, saving model to best-cifar10-v2.h5
# 1250/1250 - 33s - loss: 1.3597 - accuracy: 0.5114 - val_loss: 1.2527 - val_accuracy: 0.5550 - 33s/epoch - 26ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss improved from 1.25271 to 1.21689, saving model to best-cifar10-v2.h5
# 1250/1250 - 33s - loss: 1.2977 - accuracy: 0.5366 - val_loss: 1.2169 - val_accuracy: 0.5660 - 33s/epoch - 26ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.21689 to 1.09263, saving model to best-cifar10-v2.h5
# 1250/1250 - 34s - loss: 1.2548 - accuracy: 0.5554 - val_loss: 1.0926 - val_accuracy: 0.6094 - 34s/epoch - 27ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.09263 to 1.05232, saving model to best-cifar10-v2.h5
# 1250/1250 - 34s - loss: 1.2097 - accuracy: 0.5710 - val_loss: 1.0523 - val_accuracy: 0.6267 - 34s/epoch - 27ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss improved from 1.05232 to 0.99470, saving model to best-cifar10-v2.h5
# 1250/1250 - 33s - loss: 1.1739 - accuracy: 0.5820 - val_loss: 0.9947 - val_accuracy: 0.6468 - 33s/epoch - 26ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss did not improve from 0.99470
# 1250/1250 - 34s - loss: 1.1434 - accuracy: 0.5935 - val_loss: 1.0843 - val_accuracy: 0.6206 - 34s/epoch - 27ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.99470
# 1250/1250 - 32s - loss: 1.1189 - accuracy: 0.6066 - val_loss: 1.0024 - val_accuracy: 0.6437 - 32s/epoch - 26ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.99470 to 0.97765, saving model to best-cifar10-v2.h5
# 1250/1250 - 33s - loss: 1.0942 - accuracy: 0.6122 - val_loss: 0.9776 - val_accuracy: 0.6539 - 33s/epoch - 26ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0
ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.75197
# 1250/1250 - 32s - loss: 0.8518 - accuracy: 0.7061 - val_loss: 0.7575 - val_accuracy: 0.7400 - 32s/epoch - 26ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.75197
# 1250/1250 - 33s - loss: 0.8523 - accuracy: 0.7078 - val_loss: 0.7715 - val_accuracy: 0.7403 - 33s/epoch - 27ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss improved from 0.75197 to 0.73738, saving model to best-cifar10-v2.h5
# 1250/1250 - 32s - loss: 0.8491 - accuracy: 0.7075 - val_loss: 0.7374 - val_accuracy: 0.7486 - 32s/epoch - 26ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.73738 to 0.73259, saving model to best-cifar10-v2.h5
# 1250/1250 - 34s - loss: 0.8402 - accuracy: 0.7112 - val_loss: 0.7326 - val_accuracy: 0.7511 - 34s/epoch - 27ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss improved from 0.73259 to 0.72972, saving model to best-cifar10-v2.h5
# 1250/1250 - 32s - loss: 0.8408 - accuracy: 0.7130 - val_loss: 0.7297 - val_accuracy: 0.7493 - 32s/epoch - 26ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.72972
# 1250/1250 - 33s - loss: 0.8356 - accuracy: 0.7120 - val_loss: 0.7983 - val_accuracy: 0.7327 - 33s/epoch - 26ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss improved from 0.72972 to 0.71517, saving model to best-cifar10-v2.h5
# 1250/1250 - 33s - loss: 0.8349 - accuracy: 0.7154 - val_loss: 0.7152 - val_accuracy: 0.7567 - 33s/epoch - 26ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss improved from 0.71517 to 0.69546, saving model to best-cifar10-v2.h5
# 1250/1250 - 32s - loss: 0.8342 - accuracy: 0.7121 - val_loss: 0.6955 - val_accuracy: 0.7633 - 32s/epoch - 26ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.69546
# 1250/1250 - 32s - loss: 0.8285 - accuracy: 0.7155 - val_loss: 0.7177 - val_accuracy: 0.7578 - 32s/epoch - 26ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss did not improve from 0.69546
# 1250/1250 - 32s - loss: 0.8240 - accuracy: 0.7181 - val_loss: 0.7606 - val_accuracy: 0.7405 - 32s/epoch - 26ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.69546
# 1250/1250 - 34s - loss: 0.8268 - accuracy: 0.7165 - val_loss: 0.7321 - val_accuracy: 0.7479 - 34s/epoch - 27ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss did not improve from 0.69546
# 1250/1250 - 33s - loss: 0.8198 - accuracy: 0.7176 - val_loss: 0.7494 - val_accuracy: 0.7502 - 33s/epoch - 26ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.69546
# 1250/1250 - 34s - loss: 0.8261 - accuracy: 0.7185 - val_loss: 0.7575 - val_accuracy: 0.7444 - 34s/epoch - 27ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.69546
# 1250/1250 - 33s - loss: 0.8188 - accuracy: 0.7208 - val_loss: 0.7848 - val_accuracy: 0.7317 - 33s/epoch - 27ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.69546
# 1250/1250 - 33s - loss: 0.8191 - accuracy: 0.7204 - val_loss: 0.7618 - val_accuracy: 0.7443 - 33s/epoch - 26ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.69546
# 1250/1250 - 33s - loss: 0.8144 - accuracy: 0.7240 - val_loss: 0.7083 - val_accuracy: 0.7624 - 33s/epoch - 27ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.69546
# 1250/1250 - 32s - loss: 0.8117 - accuracy: 0.7236 - val_loss: 0.7599 - val_accuracy: 0.7383 - 32s/epoch - 26ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.69546
# 1250/1250 - 34s - loss: 0.8159 - accuracy: 0.7217 - val_loss: 0.8408 - val_accuracy: 0.7201 - 34s/epoch - 27ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.7072 - accuracy: 0.7600
# [0.7071796655654907, 0.7599999904632568]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, 'o-', ms=3, label='train accuracy')
plt.plot(xs, y_vloss, 'o-', ms=3, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('Epoch')
plt.show()

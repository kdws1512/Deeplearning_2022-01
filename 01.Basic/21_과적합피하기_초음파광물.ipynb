# %%
import numpy as np
import pandas as pd
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
from google.colab import files
up = files.upload()
filename = list(up.keys())[0]
# Out:
#      <input type="file" id="files-5f9fba8e-36f6-4229-a3c3-955d260279e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f9fba8e-36f6-4229-a3c3-955d260279e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving sonar.csv to sonar (2).csv

# %%
df = pd.read_csv(filename, header=None)
df.head(3)
# Out:
#        0       1       2       3       4   ...      56      57      58      59  60
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  ...  0.0180  0.0084  0.0090  0.0032   R
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  ...  0.0140  0.0049  0.0052  0.0044   R
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  ...  0.0316  0.0164  0.0095  0.0078   R
#
# [3 rows x 61 columns]

# %%
np.unique(df.values[:,-1], return_counts=True)
# Out:
# (array(['M', 'R'], dtype=object), array([111,  97]))

# %%
# X data: scaling
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(df.iloc[:,:-1].values)

# %%
# Y data: label encoding
from sklearn.preprocessing import LabelEncoder
y_labeled = LabelEncoder().fit_transform(df.iloc[:,-1].values)

# %%
np.array([0.1, 0.2, 'R'])
# Out:
# array(['0.1', '0.2', 'R'], dtype='<U32')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y_labeled, stratify=y_labeled, test_size=0.2, random_state=seed
)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((166, 60), (42, 60), (166,), (42,))

# %% [markdown]
# ### 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# 1. 은닉층 2

# %%
model1 = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                4880
#
#  dense_1 (Dense)             (None, 12)                972
#
#  dense_2 (Dense)             (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h1 = model1.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=50, verbose=0)
model1.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3529 - accuracy: 0.9048
# [0.3528617322444916, 0.9047619104385376]

# %% [markdown]
# - 2. 은닉층: 4개

# %%
model2 = Sequential([
    Dense(64, input_dim=60, activation='relu'),
    Dense(30, activation='relu'),
    Dense(12, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                3904
#
#  dense_9 (Dense)             (None, 30)                1950
#
#  dense_10 (Dense)            (None, 12)                372
#
#  dense_11 (Dense)            (None, 4)                 52
#
#  dense_12 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 6,283
# Trainable params: 6,283
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h2 = model2.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=50, verbose=0)
model2.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6642 - accuracy: 0.8095
# [0.6642443537712097, 0.8095238208770752]

# %% [markdown]
# - 3. 은닉층:6개

# %%
model3 = Sequential([
    Dense(64, input_dim=60, activation='relu'),
    Dense(40, activation='relu'),
    Dense(28, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(4, activation='relu'),
    Dense(1, activation='sigmoid')
])
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_13 (Dense)            (None, 64)                3904
#
#  dense_14 (Dense)            (None, 40)                2600
#
#  dense_15 (Dense)            (None, 28)                1148
#
#  dense_16 (Dense)            (None, 16)                464
#
#  dense_17 (Dense)            (None, 8)                 136
#
#  dense_18 (Dense)            (None, 4)                 36
#
#  dense_19 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 8,293
# Trainable params: 8,293
# Non-trainable params: 0
# _________________________________________________________________

# %%
model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
h3 = model3.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=50, verbose=0)
model3.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5811 - accuracy: 0.8810
# [0.5811342000961304, 0.8809523582458496]

# %% [markdown]
# - model1을 그대로 사용하는데, epoch 횟수를 늘린다.

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 80)                4880
#
#  dense_21 (Dense)            (None, 12)                972
#
#  dense_22 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(X_train, y_train, validation_split=0.2, epochs=1000, batch_size=50, verbose=0)
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5029 - accuracy: 0.9286
# [0.5029421448707581, 0.9285714030265808]

# %%
y_acc = hist.history['accuracy'][:100]
y_vloss = hist.history['val_loss'][:100]
xs = np.arange(1,len(y_acc)+1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# - 모델 저장조건 설정

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
import os
if not os.path.exists('model'):
    os.mkdir('model')

# %%
model_path = 'model/sonar.h5'
checkpoint = ModelCheckpoint(
    model_path, monitor='val_loss', verbose=1, save_best_only=True
)

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 80)                4880
#
#  dense_30 (Dense)            (None, 12)                972
#
#  dense_31 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(
    X_train, y_train, validation_split=0.2,
    epochs=400, batch_size=50, verbose=0,
    callbacks=[checkpoint]   
)
# Out:
# Epoch 00001: val_loss did not improve from 0.15112
#
# Epoch 00002: val_loss did not improve from 0.15112
#
# Epoch 00003: val_loss did not improve from 0.15112
#
# Epoch 00004: val_loss did not improve from 0.15112
#
# Epoch 00005: val_loss did not improve from 0.15112
#
# Epoch 00006: val_loss did not improve from 0.15112
#
# Epoch 00007: val_loss did not improve from 0.15112
#
# Epoch 00008: val_loss did not improve from 0.15112
#
# Epoch 00009: val_loss did not improve from 0.15112
#
# Epoch 00010: val_loss did not improve from 0.15112
#
# Epoch 00011: val_loss did not improve from 0.15112
#
# Epoch 00012: val_loss did not improve from 0.15112
#
# Epoch 00013: val_loss did not improve from 0.15112
#
# Epoch 00014: val_loss did not improve from 0.15112
#
# Epoch 00015: val_loss did not improve from 0.15112
#
# Epoch 00016: val_loss did not improve from 0.15112
#
# Epoch 00017: val_loss did not improve from 0.15112
#
# Epoch 00018: val_loss did not improve from 0.15112
#
# Epoch 00019: val_loss did not improve from 0.15112
#
# Epoch 00020: val_loss did not improve from 0.15112
#
# Epoch 00021: val_loss did not improve from 0.15112
#
# Epoch 00022: val_loss did not improve from 0.15112
#
# Epoch 00023: val_loss did not improve from 0.15112
#
# Epoch 00024: val_loss did not improve from 0.15112
#
# Epoch 00025: val_loss did not improve from 0.15112
#
# Epoch 00026: val_loss did not improve from 0.15112
#
# Epoch 00027: val_loss did not improve from 0.15112
#
# Epoch 00028: val_loss did not improve from 0.15112
#
# Epoch 00029: val_loss did not improve from 0.15112
#
# Epoch 00030: val_loss did not improve from 0.15112
#
# Epoch 00031: val_loss did not improve from 0.15112
#
# Epoch 00032: val_loss did not improve from 0.15112
#
# Epoch 00033: val_loss did not improve from 0.15112
#
# Epoch 00034: val_loss did not improve from 0.15112
#
# Epoch 00035: val_loss did not improve from 0.15112
#
# Epoch 00036: val_loss did not improve from 0.15112
#
# Epoch 00037: val_loss did not improve from 0.15112
#
# Epoch 00038: val_loss did not improve from 0.15112
#
# Epoch 00039: val_loss did not improve from 0.15112
#
# Epoch 00040: val_loss did not improve from 0.15112
#
# Epoch 00041: val_loss did not improve from 0.15112
#
# Epoch 00042: val_loss did not improve from 0.15112
#
# Epoch 00043: val_loss did not improve from 0.15112
#
# Epoch 00044: val_loss did not improve from 0.15112
#
# Epoch 00045: val_loss did not improve from 0.15112
#
# Epoch 00046: val_loss did not improve from 0.15112
#
# Epoch 00047: val_loss did not improve from 0.15112
#
# Epoch 00048: val_loss did not improve from 0.15112
#
# Epoch 00049: val_loss did not improve from 0.15112
#
# Epoch 00050: val_loss did not improve from 0.15112
#
# Epoch 00051: val_loss did not improve from 0.15112
#
# Epoch 00052: val_loss did not improve from 0.15112
#
# Epoch 00053: val_loss did not improve from 0.15112
#
# Epoch 00054: val_loss did not improve from 0.15112
#
# Epoch 00055: val_loss did not improve from 0.15112
#
# Epoch 00056: val_loss did not improve from 0.15112
#
# Epoch 00057: val_loss did not improve from 0.15112
#
# Epoch 00058: val_loss did not improve from 0.15112
#
# Epoch 00059: val_loss did not improve from 0.15112
#
# Epoch 00060: val_loss did not improve from 0.15112
#
# Epoch 00061: val_loss did not improve from 0.15112
#
# Epoch 00062: val_loss did not improve from 0.15112
#
# Epoch 00063: val_loss did not improve from 0.15112
#
# Epoch 00064: val_loss did not improve from 0.15112
#
# Epoch 00065: val_loss did not improve from 0.15112
#
# Epoch 00066: val_loss did not improve from 0.15112
#
# Epoch 00067: val_loss did not improve from 0.15112
#
# Epoch 00068: val_loss did not improve from 0.15112
#
# Epoch 00069: val_loss did not improve from 0.15112
#
# Epoch 00070: val_loss did not improve from 0.15112
#
# Epoch 00071: val_loss did not improve from 0.15112
#
# Epoch 00072: val_loss did not improve from 0.15112
#
# Epoch 00073: val_loss did not improve from 0.15112
#
# Epoch 00074: val_loss did not improve from 0.15112
#
# Epoch 00075: val_loss did not improve from 0.15112
#
# Epoch 00076: val_loss did not improve from 0.15112
#
# Epoch 00077: val_loss did not improve from 0.15112
#
# Epoch 00078: val_loss did not improve from 0.15112
#
# Epoch 00079: val_loss did not improve from 0.15112
#
# Epoch 00080: val_loss did not improve from 0.15112
#
# Epoch 00081: val_loss did not improve from 0.15112
#
# Epoch 00082: val_loss did not improve from 0.15112
#
# Epoch 00083: val_loss did not improve from 0.15112
#
# Epoch 00084: val_loss did not improve from 0.15112
#
# Epoch 00085: val_loss did not improve from 0.15112
#
# Epoch 00086: val_loss did not improve from 0.15112
#
# Epoch 00087: val_loss did not improve from 0.15112
#
# Epoch 00088: val_loss did not improve from 0.15112
#
# Epoch 00089: val_loss did not improve from 0.15112
#
# Epoch 00090: val_loss did not improve from 0.15112
#
# Epoch 00091: val_loss did not improve from 0.15112
#
# Epoch 00092: val_loss did not improve from 0.15112
#
# Epoch 00093: val_loss did not improve from 0.15112
#
# Epoch 00094: val_loss did not improve from 0.15112
#
# Epoch 00095: val_loss did not improve from 0.15112
#
# Epoch 00096: val_loss did not improve from 0.15112
#
# Epoch 00097: val_loss did not improve from 0.15112
#
# Epoch 00098: val_loss did not improve from 0.15112
#
# Epoch 00099: val_loss did not improve from 0.15112
#
# Epoch 00100: val_loss did not improve from 0.15112
#
# Epoch 00101: val_loss did not improve from 0.15112
#
# Epoch 00102: val_loss did not improve from 0.15112
#
# Epoch 00103: val_loss did not improve from 0.15112
#
# Epoch 00104: val_loss did not improve from 0.15112
#
# Epoch 00105: val_loss did not improve from 0.15112
#
# Epoch 00106: val_loss did not improve from 0.15112
#
# Epoch 00107: val_loss did not improve from 0.15112
#
# Epoch 00108: val_loss did not improve from 0.15112
#
# Epoch 00109: val_loss did not improve from 0.15112
#
# Epoch 00110: val_loss did not improve from 0.15112
#
# Epoch 00111: val_loss did not improve from 0.15112
#
# Epoch 00112: val_loss did not improve from 0.15112
#
# Epoch 00113: val_loss did not improve from 0.15112
#
# Epoch 00114: val_loss did not improve from 0.15112
#
# Epoch 00115: val_loss did not improve from 0.15112
#
# Epoch 00116: val_loss did not improve from 0.15112
#
# Epoch 00117: val_loss did not improve from 0.15112
#
# Epoch 00118: val_loss did not improve from 0.15112
#
# Epoch 00119: val_loss did not improve from 0.15112
#
# Epoch 00120: val_loss did not improve from 0.15112
#
# Epoch 00121: val_loss did not improve from 0.15112
#
# Epoch 00122: val_loss did not improve from 0.15112
#
# Epoch 00123: val_loss did not improve from 0.15112
#
# Epoch 00124: val_loss did not improve from 0.15112
#
# Epoch 00125: val_loss did not improve from 0.15112
#
# Epoch 00126: val_loss did not improve from 0.15112
#
# Epoch 00127: val_loss did not improve from 0.15112
#
# Epoch 00128: val_loss did not improve from 0.15112
#
# Epoch 00129: val_loss did not improve from 0.15112
#
# Epoch 00130: val_loss did not improve from 0.15112
#
# Epoch 00131: val_loss did not improve from 0.15112
#
# Epoch 00132: val_loss did not improve from 0.15112
#
# Epoch 00133: val_loss did not improve from 0.15112
#
# Epoch 00134: val_loss did not improve from 0.15112
#
# Epoch 00135: val_loss did not improve from 0.15112
#
# Epoch 00136: val_loss did not improve from 0.15112
#
# Epoch 00137: val_loss did not improve from 0.15112
#
# Epoch 00138: val_loss did not improve from 0.15112
#
# Epoch 00139: val_loss did not improve from 0.15112
#
# Epoch 00140: val_loss did not improve from 0.15112
#
# Epoch 00141: val_loss did not improve from 0.15112
#
# Epoch 00142: val_loss did not improve from 0.15112
#
# Epoch 00143: val_loss did not improve from 0.15112
#
# Epoch 00144: val_loss did not improve from 0.15112
#
# Epoch 00145: val_loss did not improve from 0.15112
#
# Epoch 00146: val_loss did not improve from 0.15112
#
# Epoch 00147: val_loss did not improve from 0.15112
#
# Epoch 00148: val_loss did not improve from 0.15112
#
# Epoch 00149: val_loss did not improve from 0.15112
#
# Epoch 00150: val_loss did not improve from 0.15112
#
# Epoch 00151: val_loss did not improve from 0.15112
#
# Epoch 00152: val_loss did not improve from 0.15112
#
# Epoch 00153: val_loss did not improve from 0.15112
#
# Epoch 00154: val_loss did not improve from 0.15112
#
# Epoch 00155: val_loss did not improve from 0.15112
#
# Epoch 00156: val_loss did not improve from 0.15112
#
# Epoch 00157: val_loss did not improve from 0.15112
#
# Epoch 00158: val_loss did not improve from 0.15112
#
# Epoch 00159: val_loss did not improve from 0.15112
#
# Epoch 00160: val_loss did not improve from 0.15112
#
# Epoch 00161: val_loss did not improve from 0.15112
#
# Epoch 00162: val_loss did not improve from 0.15112
#
# Epoch 00163: val_loss did not improve from 0.15112
#
# Epoch 00164: val_loss did not improve from 0.15112
#
# Epoch 00165: val_loss did not improve from 0.15112
#
# Epoch 00166: val_loss did not improve from 0.15112
#
# Epoch 00167: val_loss did not improve from 0.15112
#
# Epoch 00168: val_loss did not improve from 0.15112
#
# Epoch 00169: val_loss did not improve from 0.15112
#
# Epoch 00170: val_loss did not improve from 0.15112
#
# Epoch 00171: val_loss did not improve from 0.15112
#
# Epoch 00172: val_loss did not improve from 0.15112
#
# Epoch 00173: val_loss did not improve from 0.15112
#
# Epoch 00174: val_loss did not improve from 0.15112
#
# Epoch 00175: val_loss did not improve from 0.15112
#
# Epoch 00176: val_loss did not improve from 0.15112
#
# Epoch 00177: val_loss did not improve from 0.15112
#
# Epoch 00178: val_loss did not improve from 0.15112
#
# Epoch 00179: val_loss did not improve from 0.15112
#
# Epoch 00180: val_loss did not improve from 0.15112
#
# Epoch 00181: val_loss did not improve from 0.15112
#
# Epoch 00182: val_loss did not improve from 0.15112
#
# Epoch 00183: val_loss did not improve from 0.15112
#
# Epoch 00184: val_loss did not improve from 0.15112
#
# Epoch 00185: val_loss did not improve from 0.15112
#
# Epoch 00186: val_loss did not improve from 0.15112
#
# Epoch 00187: val_loss did not improve from 0.15112
#
# Epoch 00188: val_loss did not improve from 0.15112
#
# Epoch 00189: val_loss did not improve from 0.15112
#
# Epoch 00190: val_loss did not improve from 0.15112
#
# Epoch 00191: val_loss did not improve from 0.15112
#
# Epoch 00192: val_loss did not improve from 0.15112
#
# Epoch 00193: val_loss did not improve from 0.15112
#
# Epoch 00194: val_loss did not improve from 0.15112
#
# Epoch 00195: val_loss did not improve from 0.15112
#
# Epoch 00196: val_loss did not improve from 0.15112
#
# Epoch 00197: val_loss did not improve from 0.15112
#
# Epoch 00198: val_loss did not improve from 0.15112
#
# Epoch 00199: val_loss did not improve from 0.15112
#
# Epoch 00200: val_loss did not improve from 0.15112
#
# Epoch 00201: val_loss did not improve from 0.15112
#
# Epoch 00202: val_loss did not improve from 0.15112
#
# Epoch 00203: val_loss did not improve from 0.15112
#
# Epoch 00204: val_loss did not improve from 0.15112
#
# Epoch 00205: val_loss did not improve from 0.15112
#
# Epoch 00206: val_loss did not improve from 0.15112
#
# Epoch 00207: val_loss did not improve from 0.15112
#
# Epoch 00208: val_loss did not improve from 0.15112
#
# Epoch 00209: val_loss did not improve from 0.15112
#
# Epoch 00210: val_loss did not improve from 0.15112
#
# Epoch 00211: val_loss did not improve from 0.15112
#
# Epoch 00212: val_loss did not improve from 0.15112
#
# Epoch 00213: val_loss did not improve from 0.15112
#
# Epoch 00214: val_loss did not improve from 0.15112
#
# Epoch 00215: val_loss did not improve from 0.15112
#
# Epoch 00216: val_loss did not improve from 0.15112
#
# Epoch 00217: val_loss did not improve from 0.15112
#
# Epoch 00218: val_loss did not improve from 0.15112
#
# Epoch 00219: val_loss did not improve from 0.15112
#
# Epoch 00220: val_loss did not improve from 0.15112
#
# Epoch 00221: val_loss did not improve from 0.15112
#
# Epoch 00222: val_loss did not improve from 0.15112
#
# Epoch 00223: val_loss did not improve from 0.15112
#
# Epoch 00224: val_loss did not improve from 0.15112
#
# Epoch 00225: val_loss did not improve from 0.15112
#
# Epoch 00226: val_loss did not improve from 0.15112
#
# Epoch 00227: val_loss did not improve from 0.15112
#
# Epoch 00228: val_loss did not improve from 0.15112
#
# Epoch 00229: val_loss did not improve from 0.15112
#
# Epoch 00230: val_loss did not improve from 0.15112
#
# Epoch 00231: val_loss did not improve from 0.15112
#
# Epoch 00232: val_loss did not improve from 0.15112
#
# Epoch 00233: val_loss did not improve from 0.15112
#
# Epoch 00234: val_loss did not improve from 0.15112
#
# Epoch 00235: val_loss did not improve from 0.15112
#
# Epoch 00236: val_loss did not improve from 0.15112
#
# Epoch 00237: val_loss did not improve from 0.15112
#
# Epoch 00238: val_loss did not improve from 0.15112
#
# Epoch 00239: val_loss did not improve from 0.15112
#
# Epoch 00240: val_loss did not improve from 0.15112
#
# Epoch 00241: val_loss did not improve from 0.15112
#
# Epoch 00242: val_loss did not improve from 0.15112
#
# Epoch 00243: val_loss did not improve from 0.15112
#
# Epoch 00244: val_loss did not improve from 0.15112
#
# Epoch 00245: val_loss did not improve from 0.15112
#
# Epoch 00246: val_loss did not improve from 0.15112
#
# Epoch 00247: val_loss did not improve from 0.15112
#
# Epoch 00248: val_loss did not improve from 0.15112
#
# Epoch 00249: val_loss did not improve from 0.15112
#
# Epoch 00250: val_loss did not improve from 0.15112
#
# Epoch 00251: val_loss did not improve from 0.15112
#
# Epoch 00252: val_loss did not improve from 0.15112
#
# Epoch 00253: val_loss did not improve from 0.15112
#
# Epoch 00254: val_loss did not improve from 0.15112
#
# Epoch 00255: val_loss did not improve from 0.15112
#
# Epoch 00256: val_loss did not improve from 0.15112
#
# Epoch 00257: val_loss did not improve from 0.15112
#
# Epoch 00258: val_loss did not improve from 0.15112
#
# Epoch 00259: val_loss did not improve from 0.15112
#
# Epoch 00260: val_loss did not improve from 0.15112
#
# Epoch 00261: val_loss did not improve from 0.15112
#
# Epoch 00262: val_loss did not improve from 0.15112
#
# Epoch 00263: val_loss did not improve from 0.15112
#
# Epoch 00264: val_loss did not improve from 0.15112
#
# Epoch 00265: val_loss did not improve from 0.15112
#
# Epoch 00266: val_loss did not improve from 0.15112
#
# Epoch 00267: val_loss did not improve from 0.15112
#
# Epoch 00268: val_loss did not improve from 0.15112
#
# Epoch 00269: val_loss did not improve from 0.15112
#
# Epoch 00270: val_loss did not improve from 0.15112
#
# Epoch 00271: val_loss did not improve from 0.15112
#
# Epoch 00272: val_loss did not improve from 0.15112
#
# Epoch 00273: val_loss did not improve from 0.15112
#
# Epoch 00274: val_loss did not improve from 0.15112
#
# Epoch 00275: val_loss did not improve from 0.15112
#
# Epoch 00276: val_loss did not improve from 0.15112
#
# Epoch 00277: val_loss did not improve from 0.15112
#
# Epoch 00278: val_loss did not improve from 0.15112
#
# Epoch 00279: val_loss did not improve from 0.15112
#
# Epoch 00280: val_loss did not improve from 0.15112
#
# Epoch 00281: val_loss did not improve from 0.15112
#
# Epoch 00282: val_loss did not improve from 0.15112
#
# Epoch 00283: val_loss did not improve from 0.15112
#
# Epoch 00284: val_loss did not improve from 0.15112
#
# Epoch 00285: val_loss did not improve from 0.15112
#
# Epoch 00286: val_loss did not improve from 0.15112
#
# Epoch 00287: val_loss did not improve from 0.15112
#
# Epoch 00288: val_loss did not improve from 0.15112
#
# Epoch 00289: val_loss did not improve from 0.15112
#
# Epoch 00290: val_loss did not improve from 0.15112
#
# Epoch 00291: val_loss did not improve from 0.15112
#
# Epoch 00292: val_loss did not improve from 0.15112
#
# Epoch 00293: val_loss did not improve from 0.15112
#
# Epoch 00294: val_loss did not improve from 0.15112
#
# Epoch 00295: val_loss did not improve from 0.15112
#
# Epoch 00296: val_loss did not improve from 0.15112
#
# Epoch 00297: val_loss did not improve from 0.15112
#
# Epoch 00298: val_loss did not improve from 0.15112
#
# Epoch 00299: val_loss did not improve from 0.15112
#
# Epoch 00300: val_loss did not improve from 0.15112
#
# Epoch 00301: val_loss did not improve from 0.15112
#
# Epoch 00302: val_loss did not improve from 0.15112
#
# Epoch 00303: val_loss did not improve from 0.15112
#
# Epoch 00304: val_loss did not improve from 0.15112
#
# Epoch 00305: val_loss did not improve from 0.15112
#
# Epoch 00306: val_loss did not improve from 0.15112
#
# Epoch 00307: val_loss did not improve from 0.15112
#
# Epoch 00308: val_loss did not improve from 0.15112
#
# Epoch 00309: val_loss did not improve from 0.15112
#
# Epoch 00310: val_loss did not improve from 0.15112
#
# Epoch 00311: val_loss did not improve from 0.15112
#
# Epoch 00312: val_loss did not improve from 0.15112
#
# Epoch 00313: val_loss did not improve from 0.15112
#
# Epoch 00314: val_loss did not improve from 0.15112
#
# Epoch 00315: val_loss did not improve from 0.15112
#
# Epoch 00316: val_loss did not improve from 0.15112
#
# Epoch 00317: val_loss did not improve from 0.15112
#
# Epoch 00318: val_loss did not improve from 0.15112
#
# Epoch 00319: val_loss did not improve from 0.15112
#
# Epoch 00320: val_loss did not improve from 0.15112
#
# Epoch 00321: val_loss did not improve from 0.15112
#
# Epoch 00322: val_loss did not improve from 0.15112
#
# Epoch 00323: val_loss did not improve from 0.15112
#
# Epoch 00324: val_loss did not improve from 0.15112
#
# Epoch 00325: val_loss did not improve from 0.15112
#
# Epoch 00326: val_loss did not improve from 0.15112
#
# Epoch 00327: val_loss did not improve from 0.15112
#
# Epoch 00328: val_loss did not improve from 0.15112
#
# Epoch 00329: val_loss did not improve from 0.15112
#
# Epoch 00330: val_loss did not improve from 0.15112
#
# Epoch 00331: val_loss did not improve from 0.15112
#
# Epoch 00332: val_loss did not improve from 0.15112
#
# Epoch 00333: val_loss did not improve from 0.15112
#
# Epoch 00334: val_loss did not improve from 0.15112
#
# Epoch 00335: val_loss did not improve from 0.15112
#
# Epoch 00336: val_loss did not improve from 0.15112
#
# Epoch 00337: val_loss did not improve from 0.15112
#
# Epoch 00338: val_loss did not improve from 0.15112
#
# Epoch 00339: val_loss did not improve from 0.15112
#
# Epoch 00340: val_loss did not improve from 0.15112
#
# Epoch 00341: val_loss did not improve from 0.15112
#
# Epoch 00342: val_loss did not improve from 0.15112
#
# Epoch 00343: val_loss did not improve from 0.15112
#
# Epoch 00344: val_loss did not improve from 0.15112
#
# Epoch 00345: val_loss did not improve from 0.15112
#
# Epoch 00346: val_loss did not improve from 0.15112
#
# Epoch 00347: val_loss did not improve from 0.15112
#
# Epoch 00348: val_loss did not improve from 0.15112
#
# Epoch 00349: val_loss did not improve from 0.15112
#
# Epoch 00350: val_loss did not improve from 0.15112
#
# Epoch 00351: val_loss did not improve from 0.15112
#
# Epoch 00352: val_loss did not improve from 0.15112
#
# Epoch 00353: val_loss did not improve from 0.15112
#
# Epoch 00354: val_loss did not improve from 0.15112
#
# Epoch 00355: val_loss did not improve from 0.15112
#
# Epoch 00356: val_loss did not improve from 0.15112
#
# Epoch 00357: val_loss did not improve from 0.15112
#
# Epoch 00358: val_loss did not improve from 0.15112
#
# Epoch 00359: val_loss did not improve from 0.15112
#
# Epoch 00360: val_loss did not improve from 0.15112
#
# Epoch 00361: val_loss did not improve from 0.15112
#
# Epoch 00362: val_loss did not improve from 0.15112
#
# Epoch 00363: val_loss did not improve from 0.15112
#
# Epoch 00364: val_loss did not improve from 0.15112
#
# Epoch 00365: val_loss did not improve from 0.15112
#
# Epoch 00366: val_loss did not improve from 0.15112
#
# Epoch 00367: val_loss did not improve from 0.15112
#
# Epoch 00368: val_loss did not improve from 0.15112
#
# Epoch 00369: val_loss did not improve from 0.15112
#
# Epoch 00370: val_loss did not improve from 0.15112
#
# Epoch 00371: val_loss did not improve from 0.15112
#
# Epoch 00372: val_loss did not improve from 0.15112
#
# Epoch 00373: val_loss did not improve from 0.15112
#
# Epoch 00374: val_loss did not improve from 0.15112
#
# Epoch 00375: val_loss did not improve from 0.15112
#
# Epoch 00376: val_loss did not improve from 0.15112
#
# Epoch 00377: val_loss did not improve from 0.15112
#
# Epoch 00378: val_loss did not improve from 0.15112
#
# Epoch 00379: val_loss did not improve from 0.15112
#
# Epoch 00380: val_loss did not improve from 0.15112
#
# Epoch 00381: val_loss did not improve from 0.15112
#
# Epoch 00382: val_loss did not improve from 0.15112
#
# Epoch 00383: val_loss did not improve from 0.15112
#
# Epoch 00384: val_loss did not improve from 0.15112
#
# Epoch 00385: val_loss did not improve from 0.15112
#
# Epoch 00386: val_loss did not improve from 0.15112
#
# Epoch 00387: val_loss did not improve from 0.15112
#
# Epoch 00388: val_loss did not improve from 0.15112
#
# Epoch 00389: val_loss did not improve from 0.15112
#
# Epoch 00390: val_loss did not improve from 0.15112
#
# Epoch 00391: val_loss did not improve from 0.15112
#
# Epoch 00392: val_loss did not improve from 0.15112
#
# Epoch 00393: val_loss did not improve from 0.15112
#
# Epoch 00394: val_loss did not improve from 0.15112
#
# Epoch 00395: val_loss did not improve from 0.15112
#
# Epoch 00396: val_loss did not improve from 0.15112
#
# Epoch 00397: val_loss did not improve from 0.15112
#
# Epoch 00398: val_loss did not improve from 0.15112
#
# Epoch 00399: val_loss did not improve from 0.15112
#
# Epoch 00400: val_loss did not improve from 0.15112

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1,len(y_acc)+1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4641 - accuracy: 0.8810
# [0.46407008171081543, 0.8809523582458496]

# %%
del model

# %% [markdown]
# - 조기 종료시점 설정

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=30)

# %%
model = Sequential([
    Dense(80, input_dim=60, activation='relu'),
    Dense(12, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 80)                4880
#
#  dense_36 (Dense)            (None, 12)                972
#
#  dense_37 (Dense)            (None, 1)                 13
#
# =================================================================
# Total params: 5,865
# Trainable params: 5,865
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
hist = model.fit(
    X_train, y_train, validation_split=0.2,
    epochs=400, batch_size=50, verbose=1,
    callbacks=[checkpoint, early_stopping]   
)
# Out:
# Epoch 1/400
# 1/3 [=========>....................] - ETA: 1s - loss: 0.8748 - accuracy: 0.4600
# Epoch 00001: val_loss did not improve from 0.07201
# 3/3 [==============================] - 1s 88ms/step - loss: 0.7805 - accuracy: 0.5379 - val_loss: 0.6887 - val_accuracy: 0.6765
# Epoch 2/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.7562 - accuracy: 0.5000
# Epoch 00002: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6864 - accuracy: 0.5758 - val_loss: 0.6383 - val_accuracy: 0.7647
# Epoch 3/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5754 - accuracy: 0.7200
# Epoch 00003: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6133 - accuracy: 0.6667 - val_loss: 0.6004 - val_accuracy: 0.8235
# Epoch 4/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5947 - accuracy: 0.7600
# Epoch 00004: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5603 - accuracy: 0.7652 - val_loss: 0.5679 - val_accuracy: 0.7941
# Epoch 5/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.5793 - accuracy: 0.6800
# Epoch 00005: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5168 - accuracy: 0.7576 - val_loss: 0.5401 - val_accuracy: 0.8235
# Epoch 6/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4522 - accuracy: 0.8000
# Epoch 00006: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.4773 - accuracy: 0.8030 - val_loss: 0.5177 - val_accuracy: 0.7941
# Epoch 7/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4918 - accuracy: 0.7800
# Epoch 00007: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4454 - accuracy: 0.8333 - val_loss: 0.4964 - val_accuracy: 0.8235
# Epoch 8/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4360 - accuracy: 0.8600
# Epoch 00008: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.4146 - accuracy: 0.8636 - val_loss: 0.4792 - val_accuracy: 0.7941
# Epoch 9/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4198 - accuracy: 0.8600
# Epoch 00009: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3862 - accuracy: 0.8788 - val_loss: 0.4638 - val_accuracy: 0.7941
# Epoch 10/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.4317 - accuracy: 0.8000
# Epoch 00010: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.3595 - accuracy: 0.8864 - val_loss: 0.4485 - val_accuracy: 0.8235
# Epoch 11/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3261 - accuracy: 0.9200
# Epoch 00011: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.3343 - accuracy: 0.9015 - val_loss: 0.4335 - val_accuracy: 0.8235
# Epoch 12/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3674 - accuracy: 0.9200
# Epoch 00012: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3124 - accuracy: 0.9242 - val_loss: 0.4227 - val_accuracy: 0.8235
# Epoch 13/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3214 - accuracy: 0.9000
# Epoch 00013: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2913 - accuracy: 0.9318 - val_loss: 0.4137 - val_accuracy: 0.8235
# Epoch 14/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.3034 - accuracy: 0.9400
# Epoch 00014: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.2714 - accuracy: 0.9470 - val_loss: 0.4046 - val_accuracy: 0.8235
# Epoch 15/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2800 - accuracy: 0.9400
# Epoch 00015: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2531 - accuracy: 0.9545 - val_loss: 0.3976 - val_accuracy: 0.8235
# Epoch 16/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2466 - accuracy: 0.9400
# Epoch 00016: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.2366 - accuracy: 0.9545 - val_loss: 0.3894 - val_accuracy: 0.7941
# Epoch 17/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2819 - accuracy: 0.8800
# Epoch 00017: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2220 - accuracy: 0.9545 - val_loss: 0.3823 - val_accuracy: 0.7941
# Epoch 18/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2180 - accuracy: 0.9800
# Epoch 00018: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.2081 - accuracy: 0.9621 - val_loss: 0.3763 - val_accuracy: 0.7941
# Epoch 19/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.2060 - accuracy: 0.9400
# Epoch 00019: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1954 - accuracy: 0.9545 - val_loss: 0.3713 - val_accuracy: 0.7941
# Epoch 20/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1566 - accuracy: 0.9600
# Epoch 00020: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1832 - accuracy: 0.9545 - val_loss: 0.3668 - val_accuracy: 0.7941
# Epoch 21/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1845 - accuracy: 0.9400
# Epoch 00021: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1720 - accuracy: 0.9621 - val_loss: 0.3616 - val_accuracy: 0.7941
# Epoch 22/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1370 - accuracy: 0.9800
# Epoch 00022: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1613 - accuracy: 0.9697 - val_loss: 0.3581 - val_accuracy: 0.7941
# Epoch 23/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1477 - accuracy: 0.9800
# Epoch 00023: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1524 - accuracy: 0.9848 - val_loss: 0.3554 - val_accuracy: 0.7941
# Epoch 24/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1493 - accuracy: 1.0000
# Epoch 00024: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1440 - accuracy: 0.9924 - val_loss: 0.3526 - val_accuracy: 0.7941
# Epoch 25/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1653 - accuracy: 0.9800
# Epoch 00025: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1360 - accuracy: 0.9924 - val_loss: 0.3497 - val_accuracy: 0.7941
# Epoch 26/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1472 - accuracy: 1.0000
# Epoch 00026: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 24ms/step - loss: 0.1283 - accuracy: 0.9924 - val_loss: 0.3468 - val_accuracy: 0.7941
# Epoch 27/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1069 - accuracy: 1.0000
# Epoch 00027: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1212 - accuracy: 0.9924 - val_loss: 0.3462 - val_accuracy: 0.7941
# Epoch 28/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1179 - accuracy: 0.9800
# Epoch 00028: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1147 - accuracy: 0.9924 - val_loss: 0.3459 - val_accuracy: 0.7941
# Epoch 29/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1196 - accuracy: 1.0000
# Epoch 00029: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1090 - accuracy: 0.9924 - val_loss: 0.3437 - val_accuracy: 0.7941
# Epoch 30/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0803 - accuracy: 1.0000
# Epoch 00030: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1032 - accuracy: 0.9924 - val_loss: 0.3424 - val_accuracy: 0.7941
# Epoch 31/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.1184 - accuracy: 0.9800
# Epoch 00031: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0983 - accuracy: 0.9924 - val_loss: 0.3399 - val_accuracy: 0.7941
# Epoch 32/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0799 - accuracy: 1.0000
# Epoch 00032: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0930 - accuracy: 0.9924 - val_loss: 0.3391 - val_accuracy: 0.7941
# Epoch 33/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0634 - accuracy: 1.0000
# Epoch 00033: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0882 - accuracy: 1.0000 - val_loss: 0.3381 - val_accuracy: 0.7941
# Epoch 34/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0823 - accuracy: 1.0000
# Epoch 00034: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0837 - accuracy: 1.0000 - val_loss: 0.3373 - val_accuracy: 0.7941
# Epoch 35/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0534 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0790 - accuracy: 1.0000 - val_loss: 0.3348 - val_accuracy: 0.7941
# Epoch 36/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0663 - accuracy: 1.0000
# Epoch 00036: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0751 - accuracy: 1.0000 - val_loss: 0.3334 - val_accuracy: 0.7941
# Epoch 37/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0679 - accuracy: 1.0000
# Epoch 00037: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0709 - accuracy: 1.0000 - val_loss: 0.3303 - val_accuracy: 0.7941
# Epoch 38/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0594 - accuracy: 1.0000
# Epoch 00038: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.3273 - val_accuracy: 0.7941
# Epoch 39/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0719 - accuracy: 1.0000
# Epoch 00039: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0631 - accuracy: 1.0000 - val_loss: 0.3246 - val_accuracy: 0.7941
# Epoch 40/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0631 - accuracy: 1.0000
# Epoch 00040: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0598 - accuracy: 1.0000 - val_loss: 0.3228 - val_accuracy: 0.7941
# Epoch 41/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0783 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.3218 - val_accuracy: 0.7941
# Epoch 42/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0516 - accuracy: 1.0000
# Epoch 00042: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0534 - accuracy: 1.0000 - val_loss: 0.3210 - val_accuracy: 0.7941
# Epoch 43/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0541 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0505 - accuracy: 1.0000 - val_loss: 0.3190 - val_accuracy: 0.7941
# Epoch 44/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0604 - accuracy: 1.0000
# Epoch 00044: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0478 - accuracy: 1.0000 - val_loss: 0.3172 - val_accuracy: 0.8235
# Epoch 45/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0278 - accuracy: 1.0000
# Epoch 00045: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0452 - accuracy: 1.0000 - val_loss: 0.3161 - val_accuracy: 0.8235
# Epoch 46/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0343 - accuracy: 1.0000
# Epoch 00046: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0429 - accuracy: 1.0000 - val_loss: 0.3145 - val_accuracy: 0.8235
# Epoch 47/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0388 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0408 - accuracy: 1.0000 - val_loss: 0.3132 - val_accuracy: 0.8235
# Epoch 48/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0307 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0387 - accuracy: 1.0000 - val_loss: 0.3125 - val_accuracy: 0.8235
# Epoch 49/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0495 - accuracy: 1.0000
# Epoch 00049: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0370 - accuracy: 1.0000 - val_loss: 0.3100 - val_accuracy: 0.8235
# Epoch 50/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0394 - accuracy: 1.0000
# Epoch 00050: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0351 - accuracy: 1.0000 - val_loss: 0.3088 - val_accuracy: 0.8235
# Epoch 51/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0286 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0334 - accuracy: 1.0000 - val_loss: 0.3093 - val_accuracy: 0.8235
# Epoch 52/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0343 - accuracy: 1.0000
# Epoch 00052: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.3083 - val_accuracy: 0.8235
# Epoch 53/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0272 - accuracy: 1.0000
# Epoch 00053: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.3091 - val_accuracy: 0.8235
# Epoch 54/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0225 - accuracy: 1.0000
# Epoch 00054: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0287 - accuracy: 1.0000 - val_loss: 0.3087 - val_accuracy: 0.8235
# Epoch 55/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0257 - accuracy: 1.0000
# Epoch 00055: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.3079 - val_accuracy: 0.8235
# Epoch 56/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0208 - accuracy: 1.0000
# Epoch 00056: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0260 - accuracy: 1.0000 - val_loss: 0.3071 - val_accuracy: 0.8235
# Epoch 57/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0268 - accuracy: 1.0000
# Epoch 00057: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0248 - accuracy: 1.0000 - val_loss: 0.3061 - val_accuracy: 0.8235
# Epoch 58/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0242 - accuracy: 1.0000
# Epoch 00058: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0237 - accuracy: 1.0000 - val_loss: 0.3055 - val_accuracy: 0.8235
# Epoch 59/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 00059: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0225 - accuracy: 1.0000 - val_loss: 0.3035 - val_accuracy: 0.8235
# Epoch 60/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0185 - accuracy: 1.0000
# Epoch 00060: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0215 - accuracy: 1.0000 - val_loss: 0.3026 - val_accuracy: 0.8235
# Epoch 61/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0211 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.3018 - val_accuracy: 0.8235
# Epoch 62/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0190 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0196 - accuracy: 1.0000 - val_loss: 0.2998 - val_accuracy: 0.8235
# Epoch 63/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0146 - accuracy: 1.0000
# Epoch 00063: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.2984 - val_accuracy: 0.8235
# Epoch 64/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0239 - accuracy: 1.0000
# Epoch 00064: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.2957 - val_accuracy: 0.8235
# Epoch 65/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0151 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.2935 - val_accuracy: 0.8235
# Epoch 66/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0188 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.2931 - val_accuracy: 0.8235
# Epoch 67/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0147 - accuracy: 1.0000
# Epoch 00067: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0158 - accuracy: 1.0000 - val_loss: 0.2930 - val_accuracy: 0.8235
# Epoch 68/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0142 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0152 - accuracy: 1.0000 - val_loss: 0.2928 - val_accuracy: 0.8235
# Epoch 69/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0198 - accuracy: 1.0000
# Epoch 00069: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.2929 - val_accuracy: 0.8235
# Epoch 70/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0176 - accuracy: 1.0000
# Epoch 00070: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0140 - accuracy: 1.0000 - val_loss: 0.2922 - val_accuracy: 0.8235
# Epoch 71/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.2923 - val_accuracy: 0.8235
# Epoch 72/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0120 - accuracy: 1.0000
# Epoch 00072: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.2927 - val_accuracy: 0.8235
# Epoch 73/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0108 - accuracy: 1.0000
# Epoch 00073: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.2920 - val_accuracy: 0.8235
# Epoch 74/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0143 - accuracy: 1.0000
# Epoch 00074: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.2925 - val_accuracy: 0.8235
# Epoch 75/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0121 - accuracy: 1.0000
# Epoch 00075: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.2916 - val_accuracy: 0.8235
# Epoch 76/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0100 - accuracy: 1.0000
# Epoch 00076: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0112 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.8235
# Epoch 77/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0132 - accuracy: 1.0000
# Epoch 00077: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.8235
# Epoch 78/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000
# Epoch 00078: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.8235
# Epoch 79/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.2908 - val_accuracy: 0.8235
# Epoch 80/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00080: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.8235
# Epoch 81/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00081: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.2901 - val_accuracy: 0.8235
# Epoch 82/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0092 - accuracy: 1.0000
# Epoch 00082: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.8235
# Epoch 83/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.2884 - val_accuracy: 0.8235
# Epoch 84/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0105 - accuracy: 1.0000
# Epoch 00084: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.2881 - val_accuracy: 0.8235
# Epoch 85/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00085: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 0.2888 - val_accuracy: 0.8235
# Epoch 86/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0086 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.2885 - val_accuracy: 0.8235
# Epoch 87/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000
# Epoch 00087: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.2878 - val_accuracy: 0.8235
# Epoch 88/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00088: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.2856 - val_accuracy: 0.8235
# Epoch 89/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00089: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.2854 - val_accuracy: 0.8235
# Epoch 90/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0071 - accuracy: 1.0000
# Epoch 00090: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.8235
# Epoch 91/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0072 - accuracy: 1.0000
# Epoch 00091: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2857 - val_accuracy: 0.8235
# Epoch 92/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0084 - accuracy: 1.0000
# Epoch 00092: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.8235
# Epoch 93/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00093: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.8235
# Epoch 94/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00094: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.8235
# Epoch 95/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.8235
# Epoch 96/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0057 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.2838 - val_accuracy: 0.8235
# Epoch 97/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00097: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.8235
# Epoch 98/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0040 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.2842 - val_accuracy: 0.8235
# Epoch 99/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0066 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.8235
# Epoch 100/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00100: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.8235
# Epoch 101/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Epoch 00101: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.8235
# Epoch 102/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0048 - accuracy: 1.0000
# Epoch 00102: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.2831 - val_accuracy: 0.8235
# Epoch 103/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00103: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2832 - val_accuracy: 0.8235
# Epoch 104/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00104: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.2827 - val_accuracy: 0.8235
# Epoch 105/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 00105: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.2828 - val_accuracy: 0.8235
# Epoch 106/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0038 - accuracy: 1.0000
# Epoch 00106: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.2822 - val_accuracy: 0.8235
# Epoch 107/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0047 - accuracy: 1.0000
# Epoch 00107: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.2820 - val_accuracy: 0.8235
# Epoch 108/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00108: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2815 - val_accuracy: 0.8235
# Epoch 109/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00109: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.2810 - val_accuracy: 0.8235
# Epoch 110/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00110: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.8235
# Epoch 111/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0035 - accuracy: 1.0000
# Epoch 00111: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.8235
# Epoch 112/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00112: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.8235
# Epoch 113/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00113: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.8235
# Epoch 114/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000
# Epoch 00114: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.8235
# Epoch 115/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00115: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.8235
# Epoch 116/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00116: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.8235
# Epoch 117/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0042 - accuracy: 1.0000
# Epoch 00117: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.8235
# Epoch 118/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0039 - accuracy: 1.0000
# Epoch 00118: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.8235
# Epoch 119/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0044 - accuracy: 1.0000
# Epoch 00119: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.8235
# Epoch 120/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00120: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2806 - val_accuracy: 0.8235
# Epoch 121/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00121: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8235
# Epoch 122/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0045 - accuracy: 1.0000
# Epoch 00122: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.2798 - val_accuracy: 0.8235
# Epoch 123/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000
# Epoch 00123: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.8235
# Epoch 124/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00124: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8235
# Epoch 125/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0033 - accuracy: 1.0000
# Epoch 00125: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2808 - val_accuracy: 0.8235
# Epoch 126/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0034 - accuracy: 1.0000
# Epoch 00126: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.2807 - val_accuracy: 0.8235
# Epoch 127/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00127: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.8235
# Epoch 128/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00128: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.8235
# Epoch 129/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00129: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.8235
# Epoch 130/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00130: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2804 - val_accuracy: 0.8235
# Epoch 131/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00131: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.2801 - val_accuracy: 0.8235
# Epoch 132/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000
# Epoch 00132: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.8235
# Epoch 133/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000
# Epoch 00133: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.8235
# Epoch 134/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00134: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.8235
# Epoch 135/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00135: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.2802 - val_accuracy: 0.8235
# Epoch 136/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00136: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2797 - val_accuracy: 0.8235
# Epoch 137/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00137: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.2794 - val_accuracy: 0.8529
# Epoch 138/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00138: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2796 - val_accuracy: 0.8529
# Epoch 139/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000
# Epoch 00139: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2793 - val_accuracy: 0.8529
# Epoch 140/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0027 - accuracy: 1.0000
# Epoch 00140: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2791 - val_accuracy: 0.8529
# Epoch 141/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0021 - accuracy: 1.0000
# Epoch 00141: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.8529
# Epoch 142/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00142: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.8529
# Epoch 143/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000
# Epoch 00143: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.8529
# Epoch 144/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00144: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.8529
# Epoch 145/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00145: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.8529
# Epoch 146/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00146: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 28ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.8529
# Epoch 147/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00147: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.8529
# Epoch 148/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0025 - accuracy: 1.0000
# Epoch 00148: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2779 - val_accuracy: 0.8529
# Epoch 149/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00149: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.8529
# Epoch 150/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00150: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8529
# Epoch 151/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00151: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.8529
# Epoch 152/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000
# Epoch 00152: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.8529
# Epoch 153/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00153: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.2776 - val_accuracy: 0.8529
# Epoch 154/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00154: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2775 - val_accuracy: 0.8529
# Epoch 155/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00155: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.8529
# Epoch 156/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00156: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.8529
# Epoch 157/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0022 - accuracy: 1.0000
# Epoch 00157: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2786 - val_accuracy: 0.8529
# Epoch 158/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00158: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.8529
# Epoch 159/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00159: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.8529
# Epoch 160/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000
# Epoch 00160: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8529
# Epoch 161/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00161: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.8529
# Epoch 162/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0026 - accuracy: 1.0000
# Epoch 00162: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2786 - val_accuracy: 0.8529
# Epoch 163/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00163: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2786 - val_accuracy: 0.8529
# Epoch 164/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00164: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.8529
# Epoch 165/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00165: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8529
# Epoch 166/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00166: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2780 - val_accuracy: 0.8529
# Epoch 167/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00167: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.8529
# Epoch 168/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00168: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2786 - val_accuracy: 0.8529
# Epoch 169/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00169: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.2786 - val_accuracy: 0.8529
# Epoch 170/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00170: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2782 - val_accuracy: 0.8529
# Epoch 171/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00171: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2781 - val_accuracy: 0.8529
# Epoch 172/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00172: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.8529
# Epoch 173/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0019 - accuracy: 1.0000
# Epoch 00173: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.8529
# Epoch 174/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0015 - accuracy: 1.0000
# Epoch 00174: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8529
# Epoch 175/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00175: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.8529
# Epoch 176/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 00176: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.8529
# Epoch 177/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00177: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2783 - val_accuracy: 0.8529
# Epoch 178/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00178: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2784 - val_accuracy: 0.8529
# Epoch 179/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00179: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.2786 - val_accuracy: 0.8529
# Epoch 180/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00180: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2791 - val_accuracy: 0.8529
# Epoch 181/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00181: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.8529
# Epoch 182/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0018 - accuracy: 1.0000
# Epoch 00182: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2787 - val_accuracy: 0.8529
# Epoch 183/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 00183: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.8529
# Epoch 184/400
# 1/3 [=========>....................] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000
# Epoch 00184: val_loss did not improve from 0.07201
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.2789 - val_accuracy: 0.8529

# %%
y_acc = hist.history['accuracy'][:100]
y_vloss = hist.history['val_loss'][:100]
xs = np.arange(1,len(y_acc)+1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, ms=5, label='train accuracy')
plt.plot(xs, y_vloss, ms=5, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7110 - accuracy: 0.8333
# [0.7109500169754028, 0.8333333134651184]
